# %% [markdown]
# I.	Introduction
#     New York City – the city that never sleep, often called as New York, is the most populous and dense city in the United States.  Situated on one of the world’s largest natural harbors, New York City is the composed of five boroughs – Brooklyn, Queens, Manhattan, Bronx and Staten Island.  Based on the record – 62.7 million tourists visited New York City in 2017, especially Manhattan, attracted a large volume of tourists and visitors from all over the world every year.  Beside the most known places like: Times Square, Broadway Theater District, Rockefeller Center, and Wall Street, there are many places and things to do or to visit in New York City. Often, the first timer visiting New York City will need a guidance for choosing a place to stay, places to visit, places to shop and etc…

# %% [markdown]
# II.	Business Problem
#     Due to this demand and the growth of the travel accommodation, Travel agency starting a project of preparing a list of hotels, shopping centers, places to visit, restaurants along with the rating, address and the map for their clients.  So that their clients can be prepare and know to what to do and where to go when they arrived in New York City – the City that never sleep.
# This project is particularly useful for those visitors / tourists that is the first-time visiting New York City or a re-visit after many years.

# %% [markdown]
# III.	Target Audience
#
# This project is targeting for Tourists that are not familiar with or never been to New York City before.

# %% [markdown]
# IV.	Data
# To get all this information, we will need the following data:
# -	New York City data containing the Neighborhoods and boroughs along with latitude and longitude coordinates.  This is required to plot the map and get the venue data.
# -	Venue data for hotels, restaurants, coffee shops, shopping center so that we can analysis and explore New York City
# Data Sources that are using to extract this information
# -	New York City data with latitude and longitude coordinates can be found by using the source from the module 3 in this course:
# https://cocl.us/new_york_dataset (newyork_data.json)
# -	Use Foursquare API to get the venue data for the neighborhoods.  Foursquare API provides many categories of the venue data that we needed for this project such as; hotel, food, places to visit and etc…
# -	This project will be required using of web scrapping (open source dataset), working with Foursquare API, data cleaning, data wrangling, map visualization by using Folium and plotting the map with matplotlib.
# -	Will define all the detail data analysis in the next section - Methodology

# %% [markdown]
# V.   Methodology
#
# - Data will be collected from https://cocl.us/new_york_dataset and cleaned and processed into a dataframe.
#
# - FourSquare be used to locate all venues and then filtered by Restaurants, Hotels, Shopping center, coffee shops and likes by users will be counted and added to the dataframe.
#
# - Data will be sorted based on rankings.
#
# - Finally, the data be will be visually assessed using graphing from Python libraries.

# %% [markdown]
# Let's start by importing all the required libraries

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analysis

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handel JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # transform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.11.8  |       ha878542_0         145 KB  conda-forge
#     certifi-2020.11.8          |   py36h5fab9bb_0         150 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         392 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.6.20-hecda079_0 --> 2020.11.8-ha878542_0
#   certifi                          2020.6.20-py36h9880bd3_2 --> 2020.11.8-py36h5fab9bb_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.11.8    | 150 KB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     attrs-20.3.0               |     pyhd3deb0d_0          41 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36he6145b8_1001         347 KB  conda-forge
#     chardet-3.0.4              |py36h9880bd3_1008         194 KB  conda-forge
#     cryptography-3.2.1         |   py36h6ec43e4_0         633 KB  conda-forge
#     entrypoints-0.3            |  pyhd8ed1ab_1003           8 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     jsonschema-3.0.2           |           py36_0          87 KB  conda-forge
#     pandas-1.1.4               |   py36hd87012b_0        10.5 MB  conda-forge
#     pyopenssl-20.0.0           |     pyhd8ed1ab_0          48 KB  conda-forge
#     pyrsistent-0.17.3          |   py36h1d69622_1          89 KB  conda-forge
#     pysocks-1.7.1              |   py36h9880bd3_2          27 KB  conda-forge
#     pytz-2020.4                |     pyhd8ed1ab_0         229 KB  conda-forge
#     requests-2.25.0            |     pyhd3deb0d_0          51 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-20.3.0-pyhd3deb0d_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9880bd3_1008
#   cryptography       conda-forge/linux-64::cryptography-3.2.1-py36h6ec43e4_0
#   entrypoints        conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.0.2-py36_0
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36he6145b8_2
#   pandas             conda-forge/linux-64::pandas-1.1.4-py36hd87012b_0
#   pyopenssl          conda-forge/noarch::pyopenssl-20.0.0-pyhd8ed1ab_0
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.17.3-py36h1d69622_1
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9880bd3_2
#   pytz               conda-forge/noarch::pytz-2020.4-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.25.0-pyhd3deb0d_0
#   toolz              conda-forge/noarch::toolz-0.11.1-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# entrypoints-0.3      | 8 KB      | ##################################### | 100%
# attrs-20.3.0         | 41 KB     | ##################################### | 100%
# pyrsistent-0.17.3    | 89 KB     | ##################################### | 100%
# pytz-2020.4          | 229 KB    | ##################################### | 100%
# cryptography-3.2.1   | 633 KB    | ##################################### | 100%
# jsonschema-3.0.2     | 87 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# pandas-1.1.4         | 10.5 MB   | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 347 KB    | ##################################### | 100%
# pyopenssl-20.0.0     | 48 KB     | ##################################### | 100%
# chardet-3.0.4        | 194 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# requests-2.25.0      | 51 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# toolz-0.11.1         | 46 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# Load and explore the data
# For convenience, I am using the json file that was downloaded from the week 3 lab exercise

# %%
# loading the data
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %% [markdown]
# Transform the data into a Pandas Dataframe
# And then loop through the data and fill the data frame one row at a time

# %%
neighborhoods_data = newyork_data['features'] # define a new variable that includes this data
neighborhoods_data[0] # take a look at the first item in this list

#define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude']
#instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

#loop through the data and fill the dataframe one row at a time
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough']
    neighborhood_name = data['properties']['name']
    
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                         'Neighborhood': neighborhood_name,
                                         'Latitude': neighborhood_lat,
                                         'Longitude': neighborhood_lon}, ignore_index=True)
 
# examine the resulting dataframe
neighborhoods.head(10)
# Out:
#      Borough    Neighborhood   Latitude  Longitude
# 0      Bronx       Wakefield  40.894705 -73.847201
# 1      Bronx      Co-op City  40.874294 -73.829939
# 2      Bronx     Eastchester  40.887556 -73.827806
# 3      Bronx       Fieldston  40.895437 -73.905643
# 4      Bronx       Riverdale  40.890834 -73.912585
# 5      Bronx     Kingsbridge  40.881687 -73.902818
# 6  Manhattan     Marble Hill  40.876551 -73.910660
# 7      Bronx        Woodlawn  40.898273 -73.867315
# 8      Bronx         Norwood  40.877224 -73.879391
# 9      Bronx  Williamsbridge  40.881039 -73.857446

# %%
# make sure the dataset has all 5 boroughs and 306 neighborhoods
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
       len(neighborhoods['Borough'].unique()),
       neighborhoods.shape[0]
       
        )
     )
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# Use geopy library to get the latitude and longitude values of New York City

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent='ny_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# Create a New York City map with neighborhoods superimposed on top

# %%
# create map  of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
          [lat, lng],
          radius=5,
          popup=label,
          color='blue',
          fill=True,
          fill_color='#3186cc',
          fill_opacity=0.7,
          parse_html=False).add_to(map_newyork)
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# For this project, we are concentrating in Manhattan neighborhood for the tourists, so let's slice the original datafrane and create a new data frame of the Manhattan data

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# Get the geographical coordinates of Manhattan

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinate of Manhattan are 40.7896239, -73.9598939.

# %% [markdown]
# And now we can visualize Manhattan Neighborhoods thru the map in below:

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)

map_manhatan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have the Manhattan map, going to start utilizing the Foursaqure API to explore the neighborhoods.
# Define Foursqaure Credentials and Version

# %%
CLIENT_ID = 'HCKAPL0F5HQZMWMDE3ZY52QVJCLKD5K2AI4BQPKUH2W0P0GC' # input my Foursquare ID
CLIENT_SECRET = 'RX0PUSJJIBKDDP5TU0HIJW105XBDLWIJSVEZHY11SBPSE4OU' # input my Foursqaure secret
VERSION = '20180605' # Foursquare API version
LIMIT=100 # a default Foursquare API limit value

print('My credentails:')
print('My CLIENT_ID: ' + CLIENT_ID)
print('VERSION:' + VERSION)
# Out:
# My credentails:
# My CLIENT_ID: HCKAPL0F5HQZMWMDE3ZY52QVJCLKD5K2AI4BQPKUH2W0P0GC
# VERSION:20180605

# %% [markdown]
# Searching for all the hotels that are located in Manhattan within 1000 meters radius

# %%
search_query = 'Hotel'
radius = 1000
print('Searching for ' + search_query)
# Out:
# Searching for Hotel

# %% [markdown]
# Define the corresponding URL fo the search of hotels

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HCKAPL0F5HQZMWMDE3ZY52QVJCLKD5K2AI4BQPKUH2W0P0GC&client_secret=RX0PUSJJIBKDDP5TU0HIJW105XBDLWIJSVEZHY11SBPSE4OU&ll=40.7896239,-73.9598939&v=20180605&query=Hotel&radius=1000&limit=100'

# %% [markdown]
# Send the get request and examine the results for the search of hotels

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcbfefe2aa0530e5a44b963'},
#  'response': {'venues': [{'id': '4ad78cbff964a520140c21e3',
#     'name': 'Hotel Wales',
#     'location': {'address': '1295 Madison Ave',
#      'crossStreet': '92nd St',
#      'lat': 40.7847375,
#      'lng': -73.9557131,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7847375,
#        'lng': -73.9557131}],
#      'distance': 648,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1295 Madison Ave (92nd St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4bc3a05adce4eee125af719d',
#     'name': 'Hotel 99 Llc',
#     'location': {'address': '244 W 99th St',
#      'lat': 40.796690183128646,
#      'lng': -73.97055466621045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.796690183128646,
#        'lng': -73.97055466621045},
#       {'label': 'entrance', 'lat': 40.796684, 'lng': -73.97081}],
#      'distance': 1194,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['244 W 99th St',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '514300d3e4b0ed42766e4049',
#     'name': 'Swimming Pool @ ONE UN Plaza Hotel',
#     'location': {'address': 'Manhattan, NY',
#      'lat': 40.7902778,
#      'lng': -73.9597222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7902778,
#        'lng': -73.9597222}],
#      'distance': 74,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Manhattan, NY', 'New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '57ad7e7b498e76de45bfc3a6',
#     'name': 'Hotel Bark Ave',
#     'location': {'address': '143 East 103rd',
#      'crossStreet': 'Lexington Ave.',
#      'lat': 40.790419549617724,
#      'lng': -73.94819140434265,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.790419549617724,
#        'lng': -73.94819140434265}],
#      'distance': 990,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['143 East 103rd (Lexington Ave.)',
#       'New, NY 10029',
#       'United States']},
#     'categories': [{'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'shortName': 'Pet Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '58020e9e38fae0dde3c73496',
#     'name': 'Hotel Berkers',
#     'location': {'lat': 40.78771,
#      'lng': -73.95272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78771,
#        'lng': -73.95272}],
#      'distance': 641,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10029', 'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '509d1d6ae4b0b72b983f5245',
#     'name': 'Hotel Wales Gym',
#     'location': {'lat': 40.782543,
#      'lng': -73.958317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.782543,
#        'lng': -73.958317}],
#      'distance': 799,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10128', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '5ab98318ee628b1bcf7b3df2',
#     'name': 'West Park Hotel',
#     'location': {'lat': 40.798435,
#      'lng': -73.959826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.798435,
#        'lng': -73.959826}],
#      'distance': 980,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10025', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4ddfa9c052b16128c61da4b1',
#     'name': 'The Juicy Naam Manhattan at The Hotel Wales',
#     'location': {'address': '1295 Madison Ave Fl 2',
#      'crossStreet': 'btwn 91st St & 92nd St',
#      'lat': 40.78478240966797,
#      'lng': -73.9557113647461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78478240966797,
#        'lng': -73.9557113647461}],
#      'distance': 644,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1295 Madison Ave Fl 2 (btwn 91st St & 92nd St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '5399e702498e914689250f7c',
#     'name': 'Hotel 89',
#     'location': {'lat': 40.781426,
#      'lng': -73.953385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.781426,
#        'lng': -73.953385}],
#      'distance': 1064,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a33',
#       'name': 'Social Club',
#       'pluralName': 'Social Clubs',
#       'shortName': 'Social Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '52138f4111d25b95e26243cd',
#     'name': 'Helmsley Park Lane hotel',
#     'location': {'lat': 40.795701,
#      'lng': -73.950803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.795701,
#        'lng': -73.950803}],
#      'distance': 1022,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4f743d4fe4b0e33c0d822745',
#     'name': 'New Ebony Hotel',
#     'location': {'address': '142 W 112th St',
#      'lat': 40.800079812415824,
#      'lng': -73.95369375433997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.800079812415824,
#        'lng': -73.95369375433997},
#       {'label': 'entrance', 'lat': 40.800421, 'lng': -73.954059}],
#      'distance': 1275,
#      'postalCode': '10026',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['142 W 112th St',
#       'New York, NY 10026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '399891323'},
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4bbf930ab492d13afce3a260',
#     'name': 'The Greystone',
#     'location': {'address': '212 W 91st St',
#      'lat': 40.79097891883382,
#      'lng': -73.97391958441752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79097891883382,
#        'lng': -73.97391958441752}],
#      'distance': 1191,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['212 W 91st St',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4dcc2a1c183859f9052dc774',
#     'name': 'Karaoke',
#     'location': {'lat': 40.79477708789925,
#      'lng': -73.96730285991099,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79477708789925,
#        'lng': -73.96730285991099}],
#      'distance': 847,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120941735',
#       'name': 'Karaoke Bar',
#       'pluralName': 'Karaoke Bars',
#       'shortName': 'Karaoke',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4ab10ddcf964a520e26720e3',
#     'name': 'Lido Hall Corporation',
#     'location': {'address': '1800 Adam Clayton Powell Jr Blvd',
#      'lat': 40.799791,
#      'lng': -73.95553100000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.799791,
#        'lng': -73.95553100000001},
#       {'label': 'entrance', 'lat': 40.799823, 'lng': -73.955538}],
#      'distance': 1190,
#      'postalCode': '10026',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1800 Adam Clayton Powell Jr Blvd',
#       'New York, NY 10026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '4bdb60e32a3a0f4728c2aeb6',
#     'name': 'The Greystone Rooftop',
#     'location': {'address': '212 W 91st St',
#      'crossStreet': 'at Broadway',
#      'lat': 40.791054754304334,
#      'lng': -73.97401538124278,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.791054754304334,
#        'lng': -73.97401538124278}],
#      'distance': 1200,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['212 W 91st St (at Broadway)',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d133951735',
#       'name': 'Roof Deck',
#       'pluralName': 'Roof Decks',
#       'shortName': 'Roof Deck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False},
#    {'id': '5231508f93cd54ac37f90097',
#     'name': 'Nyinns – Extended Stay Hotels Manhattan New York',
#     'location': {'address': '244 W 99th St',
#      'lat': 40.796653747558594,
#      'lng': -73.97090911865234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.796653747558594,
#        'lng': -73.97090911865234}],
#      'distance': 1214,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['244 W 99th St',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607204606',
#     'hasPerk': False}]}}

# %%
Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_hotel = json_normalize(venues)
df_hotel.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4ad78cbff964a520140c21e3                         Hotel Wales
# 1  4bc3a05adce4eee125af719d                        Hotel 99 Llc
# 2  514300d3e4b0ed42766e4049  Swimming Pool @ ONE UN Plaza Hotel
# 3  57ad7e7b498e76de45bfc3a6                      Hotel Bark Ave
# 4  58020e9e38fae0dde3c73496                       Hotel Berkers
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1607204606    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1607204606    False
# 2  [{'id': '4bf58dd8d48988d105941735', 'name': 'G...  v-1607204606    False
# 3  [{'id': '5032897c91d4c4b30a586d69', 'name': 'P...  v-1607204606    False
# 4  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1607204606    False
#
#    location.address location.crossStreet  location.lat  location.lng  \
# 0  1295 Madison Ave              92nd St     40.784737    -73.955713
# 1     244 W 99th St                  NaN     40.796690    -73.970555
# 2     Manhattan, NY                  NaN     40.790278    -73.959722
# 3    143 East 103rd       Lexington Ave.     40.790420    -73.948191
# 4               NaN                  NaN     40.787710    -73.952720
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.7847375, 'lng'...                648
# 1  [{'label': 'display', 'lat': 40.79669018312864...               1194
# 2  [{'label': 'display', 'lat': 40.7902778, 'lng'...                 74
# 3  [{'label': 'display', 'lat': 40.79041954961772...                990
# 4  [{'label': 'display', 'lat': 40.78771, 'lng': ...                641
#
#   location.postalCode location.cc location.city location.state  \
# 0               10128          US      New York             NY
# 1               10025          US      New York             NY
# 2                 NaN          US      New York             NY
# 3               10029          US           New             NY
# 4               10029          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [1295 Madison Ave (92nd St), New York, NY 1012...
# 1    United States  [244 W 99th St, New York, NY 10025, United Sta...
# 2    United States       [Manhattan, NY, New York, NY, United States]
# 3    United States  [143 East 103rd (Lexington Ave.), New, NY 1002...
# 4    United States                [New York, NY 10029, United States]
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# Define information of interest and filter dataframe for hotel information

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_hotel.columns if col.startswith('location.')] + ['id']
df1_filtered = df_hotel.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df1_filtered['categories'] = df1_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df1_filtered.columns = [column.split('.')[-1] for column in df1_filtered.columns]

df1_filtered.head()
# Out:
#                                  name   categories           address  \
# 0                         Hotel Wales        Hotel  1295 Madison Ave
# 1                        Hotel 99 Llc        Hotel     244 W 99th St
# 2  Swimming Pool @ ONE UN Plaza Hotel     Gym Pool     Manhattan, NY
# 3                      Hotel Bark Ave  Pet Service    143 East 103rd
# 4                       Hotel Berkers      Brewery               NaN
#
#       crossStreet        lat        lng  \
# 0         92nd St  40.784737 -73.955713
# 1             NaN  40.796690 -73.970555
# 2             NaN  40.790278 -73.959722
# 3  Lexington Ave.  40.790420 -73.948191
# 4             NaN  40.787710 -73.952720
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.7847375, 'lng'...       648      10128  US
# 1  [{'label': 'display', 'lat': 40.79669018312864...      1194      10025  US
# 2  [{'label': 'display', 'lat': 40.7902778, 'lng'...        74        NaN  US
# 3  [{'label': 'display', 'lat': 40.79041954961772...       990      10029  US
# 4  [{'label': 'display', 'lat': 40.78771, 'lng': ...       641      10029  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3       New    NY  United States
# 4  New York    NY  United States
#
#                                     formattedAddress                        id
# 0  [1295 Madison Ave (92nd St), New York, NY 1012...  4ad78cbff964a520140c21e3
# 1  [244 W 99th St, New York, NY 10025, United Sta...  4bc3a05adce4eee125af719d
# 2       [Manhattan, NY, New York, NY, United States]  514300d3e4b0ed42766e4049
# 3  [143 East 103rd (Lexington Ave.), New, NY 1002...  57ad7e7b498e76de45bfc3a6
# 4                [New York, NY 10029, United States]  58020e9e38fae0dde3c73496

# %% [markdown]
# Visualizing the Hotels that are near by Manhattan

# %%
df1_filtered.name
# Out:
# 0                                          Hotel Wales
# 1                                         Hotel 99 Llc
# 2                   Swimming Pool @ ONE UN Plaza Hotel
# 3                                       Hotel Bark Ave
# 4                                        Hotel Berkers
# 5                                      Hotel Wales Gym
# 6                                      West Park Hotel
# 7          The Juicy Naam Manhattan at The Hotel Wales
# 8                                             Hotel 89
# 9                             Helmsley Park Lane hotel
# 10                                     New Ebony Hotel
# 11                                       The Greystone
# 12                                             Karaoke
# 13                               Lido Hall Corporation
# 14                               The Greystone Rooftop
# 15    Nyinns – Extended Stay Hotels Manhattan New York
# Name: name, dtype: object

# %%
# generate hotel map centred around the central Manhattan area
hotelvenues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add all the hotels in as blue circle markers
for lat, lng, label in zip(df1_filtered.lat, df1_filtered.lng, df1_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(hotelvenues_map)

# display the hotel map
hotelvenues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Searching for a list of restuarants around 1000 meters radius around Manhanttan

# %%
searchr_query = 'Restaurant'
radius=1000
print('Searching for...' + searchr_query)
# Out:
# Searching for...Restaurant

# %% [markdown]
# Define the corresponding URL for the search of restaurants

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, searchr_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HCKAPL0F5HQZMWMDE3ZY52QVJCLKD5K2AI4BQPKUH2W0P0GC&client_secret=RX0PUSJJIBKDDP5TU0HIJW105XBDLWIJSVEZHY11SBPSE4OU&ll=40.7896239,-73.9598939&v=20180605&query=Restaurant&radius=1000&limit=100'

# %% [markdown]
# Send the GET Request and examine the results for the search of restaurants

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcc093f037f4c3938b8a6a8'},
#  'response': {'venues': [{'id': '4a897cb1f964a5201f0820e3',
#     'name': '3 Guys Restaurant',
#     'location': {'address': '49 E 96th St',
#      'crossStreet': 'Madison Ave',
#      'lat': 40.787442622504265,
#      'lng': -73.95403610873488,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.787442622504265,
#        'lng': -73.95403610873488},
#       {'label': 'entrance', 'lat': 40.787227, 'lng': -73.953794}],
#      'distance': 550,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['49 E 96th St (Madison Ave)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '278300',
#      'url': 'https://www.seamless.com/menu/3-guys-96th-1381-madison-ave-new-york/278300?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=278300',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4a7778a1f964a5209be41fe3',
#     'name': "Carmine's Italian Restaurant",
#     'location': {'address': '2450 Broadway',
#      'crossStreet': 'btwn W 90th & W 91st',
#      'lat': 40.7910963,
#      'lng': -73.9739914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7910963,
#        'lng': -73.9739914}],
#      'distance': 1199,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2450 Broadway (btwn W 90th & W 91st)',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '294727',
#      'url': 'https://www.seamless.com/menu/carmines-upper-west-side-2450-broadway--new-york/294727?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294727',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4abc2282f964a5208a8620e3',
#     'name': 'Gennaro Restaurant',
#     'location': {'address': '665 Amsterdam Ave',
#      'crossStreet': 'W 93rd St',
#      'lat': 40.79193160418364,
#      'lng': -73.97193051298132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79193160418364,
#        'lng': -73.97193051298132},
#       {'label': 'entrance', 'lat': 40.79181, 'lng': -73.97178}],
#      'distance': 1046,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['665 Amsterdam Ave (W 93rd St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4a2eb2b0f964a52036981fe3',
#     'name': 'Malecon Restaurant II',
#     'location': {'address': '764 Amsterdam Ave',
#      'crossStreet': 'btw 97th St & 98th St',
#      'lat': 40.79493159833159,
#      'lng': -73.96964755745924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79493159833159,
#        'lng': -73.96964755745924},
#       {'label': 'entrance', 'lat': 40.795, 'lng': -73.969888}],
#      'distance': 1012,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['764 Amsterdam Ave (btw 97th St & 98th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1334178',
#      'url': 'https://www.seamless.com/menu/malecon-764-amsterdam-ave-new-york/1334178?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1334178',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b21779bf964a5204e3c24e3',
#     'name': "Nick's Restaurant & Pizzeria",
#     'location': {'address': '1814 2nd Ave',
#      'crossStreet': 'at E 94th St',
#      'lat': 40.78292250725332,
#      'lng': -73.94801440028694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78292250725332,
#        'lng': -73.94801440028694}],
#      'distance': 1248,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1814 2nd Ave (at E 94th St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1085037',
#      'url': 'https://www.seamless.com/menu/nicks-pizzeria-1814-2nd-ave-new-york/1085037?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1085037',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '49e61c9df964a52009641fe3',
#     'name': 'Kouzan Japanese Restaurant',
#     'location': {'address': '685 Amsterdam Ave',
#      'crossStreet': 'West 93rd St',
#      'lat': 40.79221265537916,
#      'lng': -73.97166393435015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79221265537916,
#        'lng': -73.97166393435015},
#       {'label': 'entrance', 'lat': 40.792199, 'lng': -73.971517}],
#      'distance': 1032,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['685 Amsterdam Ave (West 93rd St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '66413',
#      'url': 'https://www.seamless.com/menu/kouzan-japanese-restaurant-685-amsterdam-ave-new-york/66413?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=66413',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4aad53a2f964a520b75f20e3',
#     'name': 'Lex Restaurant',
#     'location': {'address': '1370 Lexington Ave',
#      'crossStreet': 'btwn E 90th & E 91st St',
#      'lat': 40.78253,
#      'lng': -73.9537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78253,
#        'lng': -73.9537}],
#      'distance': 946,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1370 Lexington Ave (btwn E 90th & E 91st St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '338857',
#      'url': 'https://www.seamless.com/menu/lex-restaurant-1370-lexington-ave-new-york/338857?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=338857',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '99343145'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b282b9af964a520309024e3',
#     'name': 'The New Amity Restaurant',
#     'location': {'address': '1134 Madison Ave',
#      'crossStreet': '84th St.',
#      'lat': 40.7798381,
#      'lng': -73.9598324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7798381,
#        'lng': -73.9598324}],
#      'distance': 1089,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1134 Madison Ave (84th St.)',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '72946060'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e248a5fe4cdf68591a40adf',
#     'name': "Judy's Restaurant",
#     'location': {'address': '1505 Lexington Ave',
#      'lat': 40.786680525886666,
#      'lng': -73.95038911505543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.786680525886666,
#        'lng': -73.95038911505543}],
#      'distance': 865,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1505 Lexington Ave',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4a7b0914f964a520d7e91fe3',
#     'name': "Giovanna's Restaurant",
#     'location': {'address': '1567 Lexington Ave',
#      'crossStreet': 'E. 100th Street',
#      'lat': 40.78852325970528,
#      'lng': -73.94904260868647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78852325970528,
#        'lng': -73.94904260868647},
#       {'label': 'entrance', 'lat': 40.788513, 'lng': -73.94886}],
#      'distance': 922,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1567 Lexington Ave (E. 100th Street)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4e4d9cbd4101d0d7a73e1b',
#     'name': 'El Internacional Cafe & Restaurant',
#     'location': {'address': '616 Amsterdam Ave',
#      'lat': 40.790232,
#      'lng': -73.973638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.790232,
#        'lng': -73.973638}],
#      'distance': 1160,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['616 Amsterdam Ave',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b292040f964a520459924e3',
#     'name': 'Chinatown Restaurant',
#     'location': {'address': '1650 3rd Ave',
#      'crossStreet': 'btwn E 92nd & E 93rd St',
#      'lat': 40.78274531667897,
#      'lng': -73.950934857016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78274531667897,
#        'lng': -73.950934857016}],
#      'distance': 1075,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1650 3rd Ave (btwn E 92nd & E 93rd St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfdf',
#       'name': 'Indian Chinese Restaurant',
#       'pluralName': 'Indian Chinese Restaurants',
#       'shortName': 'Indian Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '307262',
#      'url': 'https://www.seamless.com/menu/chinatown-restaurant-1650-3rd-ave-new-york/307262?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=307262',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '582804356'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4a862614f964a520960020e3',
#     'name': 'Island Restaurant',
#     'location': {'address': '1305 Madison Ave',
#      'crossStreet': 'at E 92nd St.',
#      'lat': 40.78500527012526,
#      'lng': -73.9557891850224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78500527012526,
#        'lng': -73.9557891850224},
#       {'label': 'entrance', 'lat': 40.784948, 'lng': -73.955641}],
#      'distance': 619,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1305 Madison Ave (at E 92nd St.)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b38f360f964a520e55225e3',
#     'name': "Paola's Restaurant",
#     'location': {'address': '1295 Madison Avenue',
#      'crossStreet': '92nd St',
#      'lat': 40.784654658028686,
#      'lng': -73.95586922764777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784654658028686,
#        'lng': -73.95586922764777}],
#      'distance': 648,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1295 Madison Avenue (92nd St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '76353048'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '479309d9f964a520564d1fe3',
#     'name': 'Bodrum Mediterranean Restaurant',
#     'location': {'address': '584 Amsterdam Ave',
#      'crossStreet': 'at W 88th St',
#      'lat': 40.78927368532629,
#      'lng': -73.97382498331747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78927368532629,
#        'lng': -73.97382498331747}],
#      'distance': 1174,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['584 Amsterdam Ave (at W 88th St)',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '66351',
#      'url': 'https://www.seamless.com/menu/bodrum-mediterranean-restaurant-584-amsterdam-ave-new-york/66351?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=66351',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '32829017'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f63c8e3e4b09b9cd92afeae',
#     'name': 'Mole Restaurant',
#     'location': {'address': '1735 2nd Ave',
#      'crossStreet': 'at 89th St',
#      'lat': 40.78028107601108,
#      'lng': -73.95006733166154,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78028107601108,
#        'lng': -73.95006733166154},
#       {'label': 'entrance', 'lat': 40.780277, 'lng': -73.950194}],
#      'distance': 1329,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1735 2nd Ave (at 89th St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '384150',
#      'url': 'https://www.seamless.com/menu/mole-1735-2nd-ave-new-york/384150?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=384150',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b848f2ef964a520ae3b31e3',
#     'name': 'Telio Restaurant',
#     'location': {'address': '2479 Broadway',
#      'crossStreet': 'W 92nd St',
#      'lat': 40.79229988046301,
#      'lng': -73.97349931723653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79229988046301,
#        'lng': -73.97349931723653}],
#      'distance': 1184,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2479 Broadway (W 92nd St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '66478',
#      'url': 'https://www.seamless.com/menu/telio-2479-broadway-ave-10025-new-york/66478?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=66478',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f32456319836c91c7c72940',
#     'name': 'Polonia Restaurant',
#     'location': {'address': '1398 Madison Ave',
#      'lat': 40.787883,
#      'lng': -73.954006,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.787883,
#        'lng': -73.954006},
#       {'label': 'entrance', 'lat': 40.787847, 'lng': -73.953869}],
#      'distance': 532,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1398 Madison Ave',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f32afdc19836c91c7efe4af',
#     'name': "Hanratty's Restaurant",
#     'location': {'address': '1410 Madison Ave',
#      'lat': 40.788427,
#      'lng': -73.953659,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.788427,
#        'lng': -73.953659}],
#      'distance': 542,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1410 Madison Ave',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f4404f819836ed00191ccde',
#     'name': 'Peters Restaurant',
#     'location': {'address': '1413 Madison Ave',
#      'lat': 40.78826904296875,
#      'lng': -73.95306396484375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78826904296875,
#        'lng': -73.95306396484375}],
#      'distance': 595,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1413 Madison Ave',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4e4db0bd4101d0d7a73fb2',
#     'name': "Joanna's Restaurant",
#     'location': {'address': '1295 Madison Ave',
#      'lat': 40.784768,
#      'lng': -73.955665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784768,
#        'lng': -73.955665}],
#      'distance': 647,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1295 Madison Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f32394b19836c91c7c25bba',
#     'name': 'Venezia Pizza Restaurant',
#     'location': {'address': '70 W 95th St',
#      'lat': 40.791837,
#      'lng': -73.967188,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.791837,
#        'lng': -73.967188}],
#      'distance': 662,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['70 W 95th St',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f325b1f19836c91c7cfb120',
#     'name': 'U Like Chinese Restaurant',
#     'location': {'address': '747 Columbus Ave',
#      'lat': 40.79319763183594,
#      'lng': -73.96678161621094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79319763183594,
#        'lng': -73.96678161621094}],
#      'distance': 703,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['747 Columbus Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f328ea619836c91c7e3714a',
#     'name': 'Chen Jin Diao Restaurant',
#     'location': {'address': '800 Columbus Ave',
#      'lat': 40.79498291015625,
#      'lng': -73.96637725830078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79498291015625,
#        'lng': -73.96637725830078}],
#      'distance': 808,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['800 Columbus Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f321e0a19836c91c7b7a947',
#     'name': 'Ruiz Restaurant',
#     'location': {'address': '1621 Lexington Ave',
#      'lat': 40.78970718383789,
#      'lng': -73.94783782958984,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.789759,
#        'lng': -73.947936},
#       {'label': 'display',
#        'lat': 40.78970718383789,
#        'lng': -73.94783782958984}],
#      'distance': 1016,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1621 Lexington Ave',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '5113f1e2e4b095b57d329466',
#     'name': "Lupita's Restaurant",
#     'location': {'address': '2049 2nd Ave',
#      'crossStreet': 'btwn E 105th & E 106th Sts',
#      'lat': 40.78914035356812,
#      'lng': -73.94834972264611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78914035356812,
#        'lng': -73.94834972264611}],
#      'distance': 974,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2049 2nd Ave (btwn E 105th & E 106th Sts)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f449a4e19836ed0019533a8',
#     'name': 'Ayyy Restaurant',
#     'location': {'address': '600 Columbus Ave',
#      'lat': 40.78871536254883,
#      'lng': -73.97093200683594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78871536254883,
#        'lng': -73.97093200683594}],
#      'distance': 935,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['600 Columbus Ave',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '51acad82498eb91d45146746',
#     'name': 'Central Park Restaurant',
#     'location': {'address': 'Central park',
#      'lat': 40.78690077966621,
#      'lng': -73.97111392608447,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78690077966621,
#        'lng': -73.97111392608447}],
#      'distance': 993,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Central park', 'New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108941735',
#       'name': 'Dumpling Restaurant',
#       'pluralName': 'Dumpling Restaurants',
#       'shortName': 'Dumplings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4c3aefbd413c4cc667d310',
#     'name': 'Carnegie Hill Restaurant & Coffee House',
#     'location': {'address': '1361 Lexington Ave',
#      'lat': 40.78218,
#      'lng': -73.95343000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78218,
#        'lng': -73.95343000000001}],
#      'distance': 991,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1361 Lexington Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4cf19117708060fca33af568',
#     'name': "Benny's Lung Sheng Restaurant",
#     'location': {'address': '906 Columbus Ave',
#      'crossStreet': 'btw 104th & 105th St',
#      'lat': 40.798217,
#      'lng': -73.963898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.798217,
#        'lng': -73.963898},
#       {'label': 'entrance', 'lat': 40.798251, 'lng': -73.963797}],
#      'distance': 1014,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['906 Columbus Ave (btw 104th & 105th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '5303fc3c11d250deaaf46b56',
#     'name': 'Absolute Thai Restaurant',
#     'location': {'address': '1590 Lexington Ave',
#      'crossStreet': '101st & 102nd Streets',
#      'lat': 40.78920165381754,
#      'lng': -73.94844039571389,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78920165381754,
#        'lng': -73.94844039571389}],
#      'distance': 966,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1590 Lexington Ave (101st & 102nd Streets)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f323e6c19836c91c7c463d8',
#     'name': 'Le-Se Amsterdam 732 Restaurant',
#     'location': {'address': '732 Amsterdam Ave',
#      'lat': 40.793983459472656,
#      'lng': -73.97083282470703,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.793912,
#        'lng': -73.97068},
#       {'label': 'display',
#        'lat': 40.793983459472656,
#        'lng': -73.97083282470703}],
#      'distance': 1041,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['732 Amsterdam Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4cd619bd413c4cc66c8d17',
#     'name': 'Pampa South American Restaurant',
#     'location': {'address': '768 Amsterdam Ave',
#      'lat': 40.79521179199219,
#      'lng': -73.9699478149414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79521179199219,
#        'lng': -73.9699478149414}],
#      'distance': 1051,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['768 Amsterdam Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cd941735',
#       'name': 'South American Restaurant',
#       'pluralName': 'South American Restaurants',
#       'shortName': 'South American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f32297719836c91c7bc432b',
#     'name': 'European Pizza Restaurant',
#     'location': {'address': '1626 3rd Ave',
#      'lat': 40.7824821472168,
#      'lng': -73.95164489746094,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.782467,
#        'lng': -73.951526},
#       {'label': 'display',
#        'lat': 40.7824821472168,
#        'lng': -73.95164489746094}],
#      'distance': 1056,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1626 3rd Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4ed3a608754ad8083f7d96de',
#     'name': 'Bellini Italian Restaurant & Brick Oven Pizza',
#     'location': {'address': '1660 3rd Ave',
#      'lat': 40.783269,
#      'lng': -73.951075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.783269,
#        'lng': -73.951075}],
#      'distance': 1026,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1660 3rd Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f43741a19834bc91f56f5c7',
#     'name': 'Miraldo Restaurant',
#     'location': {'address': '932 Columbus Ave',
#      'lat': 40.799135,
#      'lng': -73.96327600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.799135,
#        'lng': -73.96327600000001},
#       {'label': 'entrance', 'lat': 40.799095, 'lng': -73.963181}],
#      'distance': 1096,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['932 Columbus Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4d5d4b54775f8cfa3563c0e0',
#     'name': 'New Asia Restaurant',
#     'location': {'address': '666 Amsterdam Ave',
#      'lat': 40.79175867832696,
#      'lng': -73.972006559848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79175867832696,
#        'lng': -73.972006559848}],
#      'distance': 1048,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['666 Amsterdam Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '326254',
#      'url': 'https://www.seamless.com/menu/new-asia-chinese-restaurant-666-amsterdam-ave-new-york/326254?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=326254',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f3266bf19836c91c7d433c8',
#     'name': "Mary Ann's Mexican Restaurant",
#     'location': {'address': '1803 2nd Ave',
#      'lat': 40.782564,
#      'lng': -73.950792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.782564,
#        'lng': -73.950792}],
#      'distance': 1098,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1803 2nd Ave', 'New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4bad1afff964a520102e3be3',
#     'name': 'La Fonda Mexican Restaurant',
#     'location': {'address': '1634 Lexington Ave',
#      'crossStreet': 'East 103rd',
#      'lat': 40.79058074951172,
#      'lng': -73.94773864746094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79058074951172,
#        'lng': -73.94773864746094}],
#      'distance': 1029,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1634 Lexington Ave (East 103rd)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f8c98ace4b04a16debf7897',
#     'name': 'mi patio mexican restaurant',
#     'location': {'lat': 40.79587173461914,
#      'lng': -73.97112274169922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79587173461914,
#        'lng': -73.97112274169922}],
#      'distance': 1174,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10025', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f43f27219836ed001915c69',
#     'name': 'Jing Hua Chinese Restaurant',
#     'location': {'address': '580 Amsterdam Ave',
#      'lat': 40.789262,
#      'lng': -73.97412800000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.789262,
#        'lng': -73.97412800000001},
#       {'label': 'entrance', 'lat': 40.789206, 'lng': -73.974113}],
#      'distance': 1200,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['580 Amsterdam Ave',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4e4d9bbd4101d0d7a73e05',
#     'name': "Mary Ann's Mexican Restaurant",
#     'location': {'address': '2452 Broadway',
#      'lat': 40.791075,
#      'lng': -73.973754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.791075,
#        'lng': -73.973754},
#       {'label': 'entrance', 'lat': 40.791174, 'lng': -73.974016}],
#      'distance': 1179,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2452 Broadway',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4ae46dd7f964a5208b9a21e3',
#     'name': '3 Decker Restaurant',
#     'location': {'address': '1746 2nd Ave',
#      'crossStreet': 'E 91st St.',
#      'lat': 40.78101979159768,
#      'lng': -73.94943891830678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78101979159768,
#        'lng': -73.94943891830678},
#       {'label': 'entrance', 'lat': 40.780896, 'lng': -73.949335}],
#      'distance': 1301,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1746 2nd Ave (E 91st St.)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4f29e824e4b0e2cf5db548d7',
#     'name': "Adam's Chinese Restaurant",
#     'location': {'address': '301 E 90th St',
#      'lat': 40.78109509426577,
#      'lng': -73.94952645552087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78109509426577,
#        'lng': -73.94952645552087},
#       {'label': 'entrance', 'lat': 40.780391, 'lng': -73.949553}],
#      'distance': 1290,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['301 E 90th St',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '513a4e2fe4b06cdafa77f245',
#     'name': 'Cafe 3',
#     'location': {'address': 'Guggenheim Museum',
#      'crossStreet': 'Tower, Level 3',
#      'lat': 40.783157326457776,
#      'lng': -73.9588451385498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.783157326457776,
#        'lng': -73.9588451385498}],
#      'distance': 725,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Guggenheim Museum (Tower, Level 3)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '49c4f0b8f964a520d5561fe3',
#     'name': 'Regional',
#     'location': {'address': '2607 Broadway',
#      'crossStreet': 'btw W 98th & 99th St',
#      'lat': 40.796274774589534,
#      'lng': -73.97065558875899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.796274774589534,
#        'lng': -73.97065558875899},
#       {'label': 'entrance', 'lat': 40.796312, 'lng': -73.970884}],
#      'distance': 1170,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2607 Broadway (btw W 98th & 99th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '68085',
#      'url': 'https://www.seamless.com/menu/regional-2607-broadway-ave-new-york/68085?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=68085',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4b5a36b9f964a520b0b428e3',
#     'name': 'Pascalou',
#     'location': {'address': '1308 Madison Ave',
#      'crossStreet': 'btwn E 93rd St & E 92nd St',
#      'lat': 40.78504598683146,
#      'lng': -73.95581327084325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78504598683146,
#        'lng': -73.95581327084325}],
#      'distance': 614,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1308 Madison Ave (btwn E 93rd St & E 92nd St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '312834',
#      'url': 'https://www.seamless.com/menu/pascalou-1308-madison-ave-new-york/312834?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=312834',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '121143732'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4ac29b8af964a520f79920e3',
#     'name': 'Pio Pio Salon',
#     'location': {'address': '702 Amsterdam Ave',
#      'crossStreet': 'at W 94th St.',
#      'lat': 40.79291477271488,
#      'lng': -73.9712452854347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79291477271488,
#        'lng': -73.9712452854347},
#       {'label': 'entrance', 'lat': 40.792938, 'lng': -73.971384}],
#      'distance': 1024,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['702 Amsterdam Ave (at W 94th St.)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4eb1bfa43b7b52c0e1adc2e8',
#       'name': 'Peruvian Restaurant',
#       'pluralName': 'Peruvian Restaurants',
#       'shortName': 'Peruvian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '448470328'},
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4ca7de9db0b8236af311aee6',
#     'name': 'Subway',
#     'location': {'address': '2508 Broadway',
#      'crossStreet': 'W 94th St',
#      'lat': 40.79290231382689,
#      'lng': -73.97262791286278,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79290231382689,
#        'lng': -73.97262791286278},
#       {'label': 'entrance', 'lat': 40.792893, 'lng': -73.972762}],
#      'distance': 1133,
#      'postalCode': '10025',
#      'cc': 'US',
#      'neighborhood': 'Upper West Side',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2508 Broadway (W 94th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False},
#    {'id': '4e4cbe73bd413c4cc66bd030',
#     'name': '3 Guys',
#     'location': {'address': '1232 Madison Ave',
#      'crossStreet': 'at E 89th St.',
#      'lat': 40.78259690227818,
#      'lng': -73.95750414131378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78259690227818,
#        'lng': -73.95750414131378},
#       {'label': 'entrance', 'lat': 40.78264, 'lng': -73.957676}],
#      'distance': 807,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1232 Madison Ave (at E 89th St.)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607207231',
#     'hasPerk': False}]}}

# %% [markdown]
# Get relevant part of JSON and transform it into a dataframe

# %%
# assign relevant part of JSON to venues
rest_venues = results['response']['venues']

# tranform venues into a dataframe
df_rest = json_normalize(rest_venues)
df_rest.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                          id                          name  \
# 0  4a897cb1f964a5201f0820e3             3 Guys Restaurant
# 1  4a7778a1f964a5209be41fe3  Carmine's Italian Restaurant
# 2  4abc2282f964a5208a8620e3            Gennaro Restaurant
# 3  4a2eb2b0f964a52036981fe3         Malecon Restaurant II
# 4  4b21779bf964a5204e3c24e3  Nick's Restaurant & Pizzeria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1607207231    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607207231    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607207231    False
# 3  [{'id': '4bf58dd8d48988d1be941735', 'name': 'L...  v-1607207231    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607207231    False
#
#     location.address   location.crossStreet  location.lat  location.lng  \
# 0       49 E 96th St            Madison Ave     40.787443    -73.954036
# 1      2450 Broadway   btwn W 90th & W 91st     40.791096    -73.973991
# 2  665 Amsterdam Ave              W 93rd St     40.791932    -73.971931
# 3  764 Amsterdam Ave  btw 97th St & 98th St     40.794932    -73.969648
# 4       1814 2nd Ave           at E 94th St     40.782923    -73.948014
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.78744262250426...                550
# 1  [{'label': 'display', 'lat': 40.7910963, 'lng'...               1199
# 2  [{'label': 'display', 'lat': 40.79193160418364...               1046
# 3  [{'label': 'display', 'lat': 40.79493159833159...               1012
# 4  [{'label': 'display', 'lat': 40.78292250725332...               1248
#
#   location.postalCode location.cc location.city location.state  \
# 0               10128          US      New York             NY
# 1               10024          US      New York             NY
# 2               10025          US      New York             NY
# 3               10025          US      New York             NY
# 4               10128          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [49 E 96th St (Madison Ave), New York, NY 1012...
# 1    United States  [2450 Broadway (btwn W 90th & W 91st), New Yor...
# 2    United States  [665 Amsterdam Ave (W 93rd St), New York, NY 1...
# 3    United States  [764 Amsterdam Ave (btw 97th St & 98th St), Ne...
# 4    United States  [1814 2nd Ave (at E 94th St), New York, NY 101...
#
#   delivery.id                                       delivery.url  \
# 0      278300  https://www.seamless.com/menu/3-guys-96th-1381...
# 1      294727  https://www.seamless.com/menu/carmines-upper-w...
# 2         NaN                                                NaN
# 3     1334178  https://www.seamless.com/menu/malecon-764-amst...
# 4     1085037  https://www.seamless.com/menu/nicks-pizzeria-1...
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0               seamless  https://fastly.4sqi.net/img/general/cap/
# 1               seamless  https://fastly.4sqi.net/img/general/cap/
# 2                    NaN                                       NaN
# 3               seamless  https://fastly.4sqi.net/img/general/cap/
# 4               seamless  https://fastly.4sqi.net/img/general/cap/
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0                     [40, 50]  /delivery_provider_seamless_20180129.png
# 1                     [40, 50]  /delivery_provider_seamless_20180129.png
# 2                          NaN                                       NaN
# 3                     [40, 50]  /delivery_provider_seamless_20180129.png
# 4                     [40, 50]  /delivery_provider_seamless_20180129.png
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN

# %% [markdown]
# Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_rest.columns if col.startswith('location.')] + ['id']
df2_filtered = df_rest.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df2_filtered['categories'] = df2_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df2_filtered.columns = [column.split('.')[-1] for column in df2_filtered.columns]

df2_filtered
# Out:
#                                              name                 categories  \
# 0                               3 Guys Restaurant                      Diner
# 1                    Carmine's Italian Restaurant         Italian Restaurant
# 2                              Gennaro Restaurant         Italian Restaurant
# 3                           Malecon Restaurant II  Latin American Restaurant
# 4                    Nick's Restaurant & Pizzeria                Pizza Place
# 5                      Kouzan Japanese Restaurant           Sushi Restaurant
# 6                                  Lex Restaurant         Italian Restaurant
# 7                        The New Amity Restaurant                      Diner
# 8                               Judy's Restaurant  Latin American Restaurant
# 9                           Giovanna's Restaurant         Italian Restaurant
# 10             El Internacional Cafe & Restaurant                       Café
# 11                           Chinatown Restaurant  Indian Chinese Restaurant
# 12                              Island Restaurant        American Restaurant
# 13                             Paola's Restaurant                 Restaurant
# 14                Bodrum Mediterranean Restaurant         Turkish Restaurant
# 15                                Mole Restaurant         Mexican Restaurant
# 16                               Telio Restaurant           Greek Restaurant
# 17                             Polonia Restaurant                       Food
# 18                          Hanratty's Restaurant                       Food
# 19                              Peters Restaurant                       Food
# 20                            Joanna's Restaurant        American Restaurant
# 21                       Venezia Pizza Restaurant                Pizza Place
# 22                      U Like Chinese Restaurant         Chinese Restaurant
# 23                       Chen Jin Diao Restaurant                       Food
# 24                                Ruiz Restaurant                       Food
# 25                            Lupita's Restaurant         Mexican Restaurant
# 26                                Ayyy Restaurant                       Food
# 27                        Central Park Restaurant        Dumpling Restaurant
# 28        Carnegie Hill Restaurant & Coffee House                Coffee Shop
# 29                  Benny's Lung Sheng Restaurant         Chinese Restaurant
# 30                       Absolute Thai Restaurant            Thai Restaurant
# 31                 Le-Se Amsterdam 732 Restaurant                       Food
# 32                Pampa South American Restaurant  South American Restaurant
# 33                      European Pizza Restaurant                       Food
# 34  Bellini Italian Restaurant & Brick Oven Pizza         Italian Restaurant
# 35                             Miraldo Restaurant                       Food
# 36                            New Asia Restaurant         Chinese Restaurant
# 37                  Mary Ann's Mexican Restaurant         Mexican Restaurant
# 38                    La Fonda Mexican Restaurant         Mexican Restaurant
# 39                    mi patio mexican restaurant         Mexican Restaurant
# 40                    Jing Hua Chinese Restaurant         Chinese Restaurant
# 41                  Mary Ann's Mexican Restaurant         Mexican Restaurant
# 42                            3 Decker Restaurant                      Diner
# 43                      Adam's Chinese Restaurant           Asian Restaurant
# 44                                         Cafe 3                       Café
# 45                                       Regional         Italian Restaurant
# 46                                       Pascalou          French Restaurant
# 47                                  Pio Pio Salon        Peruvian Restaurant
# 48                                         Subway             Sandwich Place
# 49                                         3 Guys                      Diner
#
#                 address                 crossStreet        lat        lng  \
# 0          49 E 96th St                 Madison Ave  40.787443 -73.954036
# 1         2450 Broadway        btwn W 90th & W 91st  40.791096 -73.973991
# 2     665 Amsterdam Ave                   W 93rd St  40.791932 -73.971931
# 3     764 Amsterdam Ave       btw 97th St & 98th St  40.794932 -73.969648
# 4          1814 2nd Ave                at E 94th St  40.782923 -73.948014
# 5     685 Amsterdam Ave                West 93rd St  40.792213 -73.971664
# 6    1370 Lexington Ave     btwn E 90th & E 91st St  40.782530 -73.953700
# 7      1134 Madison Ave                    84th St.  40.779838 -73.959832
# 8    1505 Lexington Ave                         NaN  40.786681 -73.950389
# 9    1567 Lexington Ave             E. 100th Street  40.788523 -73.949043
# 10    616 Amsterdam Ave                         NaN  40.790232 -73.973638
# 11         1650 3rd Ave     btwn E 92nd & E 93rd St  40.782745 -73.950935
# 12     1305 Madison Ave               at E 92nd St.  40.785005 -73.955789
# 13  1295 Madison Avenue                     92nd St  40.784655 -73.955869
# 14    584 Amsterdam Ave                at W 88th St  40.789274 -73.973825
# 15         1735 2nd Ave                  at 89th St  40.780281 -73.950067
# 16        2479 Broadway                   W 92nd St  40.792300 -73.973499
# 17     1398 Madison Ave                         NaN  40.787883 -73.954006
# 18     1410 Madison Ave                         NaN  40.788427 -73.953659
# 19     1413 Madison Ave                         NaN  40.788269 -73.953064
# 20     1295 Madison Ave                         NaN  40.784768 -73.955665
# 21         70 W 95th St                         NaN  40.791837 -73.967188
# 22     747 Columbus Ave                         NaN  40.793198 -73.966782
# 23     800 Columbus Ave                         NaN  40.794983 -73.966377
# 24   1621 Lexington Ave                         NaN  40.789707 -73.947838
# 25         2049 2nd Ave  btwn E 105th & E 106th Sts  40.789140 -73.948350
# 26     600 Columbus Ave                         NaN  40.788715 -73.970932
# 27         Central park                         NaN  40.786901 -73.971114
# 28   1361 Lexington Ave                         NaN  40.782180 -73.953430
# 29     906 Columbus Ave        btw 104th & 105th St  40.798217 -73.963898
# 30   1590 Lexington Ave       101st & 102nd Streets  40.789202 -73.948440
# 31    732 Amsterdam Ave                         NaN  40.793983 -73.970833
# 32    768 Amsterdam Ave                         NaN  40.795212 -73.969948
# 33         1626 3rd Ave                         NaN  40.782482 -73.951645
# 34         1660 3rd Ave                         NaN  40.783269 -73.951075
# 35     932 Columbus Ave                         NaN  40.799135 -73.963276
# 36    666 Amsterdam Ave                         NaN  40.791759 -73.972007
# 37         1803 2nd Ave                         NaN  40.782564 -73.950792
# 38   1634 Lexington Ave                  East 103rd  40.790581 -73.947739
# 39                  NaN                         NaN  40.795872 -73.971123
# 40    580 Amsterdam Ave                         NaN  40.789262 -73.974128
# 41        2452 Broadway                         NaN  40.791075 -73.973754
# 42         1746 2nd Ave                  E 91st St.  40.781020 -73.949439
# 43        301 E 90th St                         NaN  40.781095 -73.949526
# 44    Guggenheim Museum              Tower, Level 3  40.783157 -73.958845
# 45        2607 Broadway        btw W 98th & 99th St  40.796275 -73.970656
# 46     1308 Madison Ave  btwn E 93rd St & E 92nd St  40.785046 -73.955813
# 47    702 Amsterdam Ave               at W 94th St.  40.792915 -73.971245
# 48        2508 Broadway                   W 94th St  40.792902 -73.972628
# 49     1232 Madison Ave               at E 89th St.  40.782597 -73.957504
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.78744262250426...       550      10128
# 1   [{'label': 'display', 'lat': 40.7910963, 'lng'...      1199      10024
# 2   [{'label': 'display', 'lat': 40.79193160418364...      1046      10025
# 3   [{'label': 'display', 'lat': 40.79493159833159...      1012      10025
# 4   [{'label': 'display', 'lat': 40.78292250725332...      1248      10128
# 5   [{'label': 'display', 'lat': 40.79221265537916...      1032      10025
# 6   [{'label': 'display', 'lat': 40.78253, 'lng': ...       946      10128
# 7   [{'label': 'display', 'lat': 40.7798381, 'lng'...      1089      10028
# 8   [{'label': 'display', 'lat': 40.78668052588666...       865      10029
# 9   [{'label': 'display', 'lat': 40.78852325970528...       922      10029
# 10  [{'label': 'display', 'lat': 40.790232, 'lng':...      1160      10024
# 11  [{'label': 'display', 'lat': 40.78274531667897...      1075      10128
# 12  [{'label': 'display', 'lat': 40.78500527012526...       619      10128
# 13  [{'label': 'display', 'lat': 40.78465465802868...       648      10128
# 14  [{'label': 'display', 'lat': 40.78927368532629...      1174      10024
# 15  [{'label': 'display', 'lat': 40.78028107601108...      1329      10128
# 16  [{'label': 'display', 'lat': 40.79229988046301...      1184      10025
# 17  [{'label': 'display', 'lat': 40.787883, 'lng':...       532      10029
# 18  [{'label': 'display', 'lat': 40.788427, 'lng':...       542      10029
# 19  [{'label': 'display', 'lat': 40.78826904296875...       595      10029
# 20  [{'label': 'display', 'lat': 40.784768, 'lng':...       647      10128
# 21  [{'label': 'display', 'lat': 40.791837, 'lng':...       662      10025
# 22  [{'label': 'display', 'lat': 40.79319763183594...       703      10025
# 23  [{'label': 'display', 'lat': 40.79498291015625...       808      10025
# 24  [{'label': 'entrance', 'lat': 40.789759, 'lng'...      1016      10029
# 25  [{'label': 'display', 'lat': 40.78914035356812...       974      10029
# 26  [{'label': 'display', 'lat': 40.78871536254883...       935      10024
# 27  [{'label': 'display', 'lat': 40.78690077966621...       993        NaN
# 28  [{'label': 'display', 'lat': 40.78218, 'lng': ...       991      10128
# 29  [{'label': 'display', 'lat': 40.798217, 'lng':...      1014      10025
# 30  [{'label': 'display', 'lat': 40.78920165381754...       966      10029
# 31  [{'label': 'entrance', 'lat': 40.793912, 'lng'...      1041      10025
# 32  [{'label': 'display', 'lat': 40.79521179199219...      1051      10025
# 33  [{'label': 'entrance', 'lat': 40.782467, 'lng'...      1056      10128
# 34  [{'label': 'display', 'lat': 40.783269, 'lng':...      1026      10128
# 35  [{'label': 'display', 'lat': 40.799135, 'lng':...      1096      10025
# 36  [{'label': 'display', 'lat': 40.79175867832696...      1048      10025
# 37  [{'label': 'display', 'lat': 40.782564, 'lng':...      1098        NaN
# 38  [{'label': 'display', 'lat': 40.79058074951172...      1029      10029
# 39  [{'label': 'display', 'lat': 40.79587173461914...      1174      10025
# 40  [{'label': 'display', 'lat': 40.789262, 'lng':...      1200      10024
# 41  [{'label': 'display', 'lat': 40.791075, 'lng':...      1179      10024
# 42  [{'label': 'display', 'lat': 40.78101979159768...      1301      10128
# 43  [{'label': 'display', 'lat': 40.78109509426577...      1290      10128
# 44  [{'label': 'display', 'lat': 40.78315732645777...       725      10128
# 45  [{'label': 'display', 'lat': 40.79627477458953...      1170      10025
# 46  [{'label': 'display', 'lat': 40.78504598683146...       614      10128
# 47  [{'label': 'display', 'lat': 40.79291477271488...      1024      10025
# 48  [{'label': 'display', 'lat': 40.79290231382689...      1133      10025
# 49  [{'label': 'display', 'lat': 40.78259690227818...       807      10128
#
#     cc      city state        country  \
# 0   US  New York    NY  United States
# 1   US  New York    NY  United States
# 2   US  New York    NY  United States
# 3   US  New York    NY  United States
# 4   US  New York    NY  United States
# 5   US  New York    NY  United States
# 6   US  New York    NY  United States
# 7   US  New York    NY  United States
# 8   US  New York    NY  United States
# 9   US  New York    NY  United States
# 10  US  New York    NY  United States
# 11  US  New York    NY  United States
# 12  US  New York    NY  United States
# 13  US  New York    NY  United States
# 14  US  New York    NY  United States
# 15  US  New York    NY  United States
# 16  US  New York    NY  United States
# 17  US  New York    NY  United States
# 18  US  New York    NY  United States
# 19  US  New York    NY  United States
# 20  US  New York    NY  United States
# 21  US  New York    NY  United States
# 22  US  New York    NY  United States
# 23  US  New York    NY  United States
# 24  US  New York    NY  United States
# 25  US  New York    NY  United States
# 26  US  New York    NY  United States
# 27  US  New York    NY  United States
# 28  US  New York    NY  United States
# 29  US  New York    NY  United States
# 30  US  New York    NY  United States
# 31  US  New York    NY  United States
# 32  US  New York    NY  United States
# 33  US  New York    NY  United States
# 34  US  New York    NY  United States
# 35  US  New York    NY  United States
# 36  US  New York    NY  United States
# 37  US  New York    NY  United States
# 38  US  New York    NY  United States
# 39  US  New York    NY  United States
# 40  US  New York    NY  United States
# 41  US  New York    NY  United States
# 42  US  New York    NY  United States
# 43  US  New York    NY  United States
# 44  US  New York    NY  United States
# 45  US  New York    NY  United States
# 46  US  New York    NY  United States
# 47  US  New York    NY  United States
# 48  US  New York    NY  United States
# 49  US  New York    NY  United States
#
#                                      formattedAddress     neighborhood  \
# 0   [49 E 96th St (Madison Ave), New York, NY 1012...              NaN
# 1   [2450 Broadway (btwn W 90th & W 91st), New Yor...              NaN
# 2   [665 Amsterdam Ave (W 93rd St), New York, NY 1...              NaN
# 3   [764 Amsterdam Ave (btw 97th St & 98th St), Ne...              NaN
# 4   [1814 2nd Ave (at E 94th St), New York, NY 101...              NaN
# 5   [685 Amsterdam Ave (West 93rd St), New York, N...              NaN
# 6   [1370 Lexington Ave (btwn E 90th & E 91st St),...              NaN
# 7   [1134 Madison Ave (84th St.), New York, NY 100...              NaN
# 8   [1505 Lexington Ave, New York, NY 10029, Unite...              NaN
# 9   [1567 Lexington Ave (E. 100th Street), New Yor...              NaN
# 10  [616 Amsterdam Ave, New York, NY 10024, United...              NaN
# 11  [1650 3rd Ave (btwn E 92nd & E 93rd St), New Y...              NaN
# 12  [1305 Madison Ave (at E 92nd St.), New York, N...              NaN
# 13  [1295 Madison Avenue (92nd St), New York, NY 1...              NaN
# 14  [584 Amsterdam Ave (at W 88th St), New York, N...              NaN
# 15  [1735 2nd Ave (at 89th St), New York, NY 10128...              NaN
# 16  [2479 Broadway (W 92nd St), New York, NY 10025...              NaN
# 17  [1398 Madison Ave, New York, NY 10029, United ...              NaN
# 18  [1410 Madison Ave, New York, NY 10029, United ...              NaN
# 19  [1413 Madison Ave, New York, NY 10029, United ...              NaN
# 20  [1295 Madison Ave, New York, NY 10128, United ...              NaN
# 21  [70 W 95th St, New York, NY 10025, United States]              NaN
# 22  [747 Columbus Ave, New York, NY 10025, United ...              NaN
# 23  [800 Columbus Ave, New York, NY 10025, United ...              NaN
# 24  [1621 Lexington Ave, New York, NY 10029, Unite...              NaN
# 25  [2049 2nd Ave (btwn E 105th & E 106th Sts), Ne...              NaN
# 26  [600 Columbus Ave, New York, NY 10024, United ...              NaN
# 27        [Central park, New York, NY, United States]              NaN
# 28  [1361 Lexington Ave, New York, NY 10128, Unite...              NaN
# 29  [906 Columbus Ave (btw 104th & 105th St), New ...              NaN
# 30  [1590 Lexington Ave (101st & 102nd Streets), N...              NaN
# 31  [732 Amsterdam Ave, New York, NY 10025, United...              NaN
# 32  [768 Amsterdam Ave, New York, NY 10025, United...              NaN
# 33  [1626 3rd Ave, New York, NY 10128, United States]              NaN
# 34  [1660 3rd Ave, New York, NY 10128, United States]              NaN
# 35  [932 Columbus Ave, New York, NY 10025, United ...              NaN
# 36  [666 Amsterdam Ave, New York, NY 10025, United...              NaN
# 37        [1803 2nd Ave, New York, NY, United States]              NaN
# 38  [1634 Lexington Ave (East 103rd), New York, NY...              NaN
# 39                [New York, NY 10025, United States]              NaN
# 40  [580 Amsterdam Ave, New York, NY 10024, United...              NaN
# 41  [2452 Broadway, New York, NY 10024, United Sta...              NaN
# 42  [1746 2nd Ave (E 91st St.), New York, NY 10128...              NaN
# 43  [301 E 90th St, New York, NY 10128, United Sta...              NaN
# 44  [Guggenheim Museum (Tower, Level 3), New York,...              NaN
# 45  [2607 Broadway (btw W 98th & 99th St), New Yor...              NaN
# 46  [1308 Madison Ave (btwn E 93rd St & E 92nd St)...              NaN
# 47  [702 Amsterdam Ave (at W 94th St.), New York, ...              NaN
# 48  [2508 Broadway (W 94th St), New York, NY 10025...  Upper West Side
# 49  [1232 Madison Ave (at E 89th St.), New York, N...              NaN
#
#                           id
# 0   4a897cb1f964a5201f0820e3
# 1   4a7778a1f964a5209be41fe3
# 2   4abc2282f964a5208a8620e3
# 3   4a2eb2b0f964a52036981fe3
# 4   4b21779bf964a5204e3c24e3
# 5   49e61c9df964a52009641fe3
# 6   4aad53a2f964a520b75f20e3
# 7   4b282b9af964a520309024e3
# 8   4e248a5fe4cdf68591a40adf
# 9   4a7b0914f964a520d7e91fe3
# 10  4e4e4d9cbd4101d0d7a73e1b
# 11  4b292040f964a520459924e3
# 12  4a862614f964a520960020e3
# 13  4b38f360f964a520e55225e3
# 14  479309d9f964a520564d1fe3
# 15  4f63c8e3e4b09b9cd92afeae
# 16  4b848f2ef964a520ae3b31e3
# 17  4f32456319836c91c7c72940
# 18  4f32afdc19836c91c7efe4af
# 19  4f4404f819836ed00191ccde
# 20  4e4e4db0bd4101d0d7a73fb2
# 21  4f32394b19836c91c7c25bba
# 22  4f325b1f19836c91c7cfb120
# 23  4f328ea619836c91c7e3714a
# 24  4f321e0a19836c91c7b7a947
# 25  5113f1e2e4b095b57d329466
# 26  4f449a4e19836ed0019533a8
# 27  51acad82498eb91d45146746
# 28  4e4c3aefbd413c4cc667d310
# 29  4cf19117708060fca33af568
# 30  5303fc3c11d250deaaf46b56
# 31  4f323e6c19836c91c7c463d8
# 32  4e4cd619bd413c4cc66c8d17
# 33  4f32297719836c91c7bc432b
# 34  4ed3a608754ad8083f7d96de
# 35  4f43741a19834bc91f56f5c7
# 36  4d5d4b54775f8cfa3563c0e0
# 37  4f3266bf19836c91c7d433c8
# 38  4bad1afff964a520102e3be3
# 39  4f8c98ace4b04a16debf7897
# 40  4f43f27219836ed001915c69
# 41  4e4e4d9bbd4101d0d7a73e05
# 42  4ae46dd7f964a5208b9a21e3
# 43  4f29e824e4b0e2cf5db548d7
# 44  513a4e2fe4b06cdafa77f245
# 45  49c4f0b8f964a520d5561fe3
# 46  4b5a36b9f964a520b0b428e3
# 47  4ac29b8af964a520f79920e3
# 48  4ca7de9db0b8236af311aee6
# 49  4e4cbe73bd413c4cc66bd030

# %% [markdown]
# Visualizing the restuarants that are near by

# %%
df2_filtered.name
# Out:
# 0                                 3 Guys Restaurant
# 1                      Carmine's Italian Restaurant
# 2                                Gennaro Restaurant
# 3                             Malecon Restaurant II
# 4                      Nick's Restaurant & Pizzeria
# 5                        Kouzan Japanese Restaurant
# 6                                    Lex Restaurant
# 7                          The New Amity Restaurant
# 8                                 Judy's Restaurant
# 9                             Giovanna's Restaurant
# 10               El Internacional Cafe & Restaurant
# 11                             Chinatown Restaurant
# 12                                Island Restaurant
# 13                               Paola's Restaurant
# 14                  Bodrum Mediterranean Restaurant
# 15                                  Mole Restaurant
# 16                                 Telio Restaurant
# 17                               Polonia Restaurant
# 18                            Hanratty's Restaurant
# 19                                Peters Restaurant
# 20                              Joanna's Restaurant
# 21                         Venezia Pizza Restaurant
# 22                        U Like Chinese Restaurant
# 23                         Chen Jin Diao Restaurant
# 24                                  Ruiz Restaurant
# 25                              Lupita's Restaurant
# 26                                  Ayyy Restaurant
# 27                          Central Park Restaurant
# 28          Carnegie Hill Restaurant & Coffee House
# 29                    Benny's Lung Sheng Restaurant
# 30                         Absolute Thai Restaurant
# 31                   Le-Se Amsterdam 732 Restaurant
# 32                  Pampa South American Restaurant
# 33                        European Pizza Restaurant
# 34    Bellini Italian Restaurant & Brick Oven Pizza
# 35                               Miraldo Restaurant
# 36                              New Asia Restaurant
# 37                    Mary Ann's Mexican Restaurant
# 38                      La Fonda Mexican Restaurant
# 39                      mi patio mexican restaurant
# 40                      Jing Hua Chinese Restaurant
# 41                    Mary Ann's Mexican Restaurant
# 42                              3 Decker Restaurant
# 43                        Adam's Chinese Restaurant
# 44                                           Cafe 3
# 45                                         Regional
# 46                                         Pascalou
# 47                                    Pio Pio Salon
# 48                                           Subway
# 49                                           3 Guys
# Name: name, dtype: object

# %%
# generate a restaurant map centred around Manhattan area
restvenues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add the restaurants as blue circle markers
for lat, lng, label in zip(df2_filtered.lat, df2_filtered.lng, df2_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(restvenues_map)

# display map
restvenues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Searching for coffee shops in Manhattan around 1000 meters radius area

# %%
searchco_query = 'Coffee'
radius = 1000
print('searching for...' + searchco_query)
# Out:
# searching for...Coffee

# %% [markdown]
# Define the corresponding URL for the search of coffee shops

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, searchco_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HCKAPL0F5HQZMWMDE3ZY52QVJCLKD5K2AI4BQPKUH2W0P0GC&client_secret=RX0PUSJJIBKDDP5TU0HIJW105XBDLWIJSVEZHY11SBPSE4OU&ll=40.7896239,-73.9598939&v=20180605&query=Coffee&radius=1000&limit=100'

# %% [markdown]
# Send the GET Request and examine the results for the search of coffee shops

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcc0de91d30726847eca353'},
#  'response': {'venues': [{'id': '5177d30c498e9b657328e30f',
#     'name': 'Coffee Cart - 97th & Columbus',
#     'location': {'address': 'W 97th Street',
#      'crossStreet': 'Columbus Ave',
#      'lat': 40.79462883157771,
#      'lng': -73.96660262569878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79462883157771,
#        'lng': -73.96660262569878}],
#      'distance': 793,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['W 97th Street (Columbus Ave)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4d2fb1575acfa35d7065f2cb',
#     'name': 'Coffee Cart - 96th St',
#     'location': {'address': '96th St.',
#      'crossStreet': 'Central Park West',
#      'lat': 40.79175386492058,
#      'lng': -73.96486350841194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79175386492058,
#        'lng': -73.96486350841194}],
#      'distance': 481,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['96th St. (Central Park West)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '58a5d1d426a95370d3355e0d',
#     'name': 'WFM Coffee Bar',
#     'location': {'address': '808 Columbus Ave',
#      'lat': 40.795145,
#      'lng': -73.965855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.795145,
#        'lng': -73.965855}],
#      'distance': 793,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['808 Columbus Ave',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '5037e21fe4b0b68ee3d6546f',
#     'name': 'Birch Coffee',
#     'location': {'address': '750 Columbus Ave',
#      'crossStreet': 'btwn W 96th & W 97th St',
#      'lat': 40.79313058780598,
#      'lng': -73.96724078166824,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79313058780598,
#        'lng': -73.96724078166824}],
#      'distance': 731,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['750 Columbus Ave (btwn W 96th & W 97th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4d53548e2f638cfa759e616a',
#     'name': 'Coffee',
#     'location': {'address': '43rd And 11th Ave',
#      'lat': 40.79258171403207,
#      'lng': -73.96515623222184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79258171403207,
#        'lng': -73.96515623222184}],
#      'distance': 552,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['43rd And 11th Ave',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4dca7fde1f6e28126777d908',
#     'name': 'Coffee Cart',
#     'location': {'address': '85th and Lexington',
#      'lat': 40.77968253446027,
#      'lng': -73.95751082933785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77968253446027,
#        'lng': -73.95751082933785}],
#      'distance': 1124,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['85th and Lexington',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4f6243bae4b0a20e1e91aabf',
#     'name': 'Coffee Cart - 103rd St',
#     'location': {'address': '103rd Street',
#      'crossStreet': 'CPW',
#      'lat': 40.79606561476228,
#      'lng': -73.96158611933654,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79606561476228,
#        'lng': -73.96158611933654}],
#      'distance': 731,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103rd Street (CPW)',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '5a772c1625ecca5ea8cd01cd',
#     'name': 'Frenchy Coffee',
#     'location': {'address': '129 E 102nd St',
#      'lat': 40.7898734,
#      'lng': -73.9483415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7898734,
#        'lng': -73.9483415}],
#      'distance': 974,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['129 E 102nd St',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1388518',
#      'url': 'https://www.seamless.com/menu/frenchy-coffee-nyc-129-e-102nd-st-new-york/1388518?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1388518',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4fdb2abfe4b0cbb58909cb7b',
#     'name': 'Coffee & Donuts Cart',
#     'location': {'address': '92nd Street & Columbus',
#      'lat': 40.790061950683594,
#      'lng': -73.96914672851562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.790061950683594,
#        'lng': -73.96914672851562}],
#      'distance': 781,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['92nd Street & Columbus',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4bdb92b7383276b0c8b67369',
#     'name': 'Coffee Cart - 98th & Madison',
#     'location': {'address': '98th Street',
#      'crossStreet': 'Madison Avenue (South East Corner)',
#      'lat': 40.78852683326035,
#      'lng': -73.95301643089606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78852683326035,
#        'lng': -73.95301643089606}],
#      'distance': 592,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['98th Street (Madison Avenue (South East Corner))',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '5b784d8d037be1002c195155',
#     'name': 'Jack’s Stir Brew Coffee',
#     'location': {'lat': 40.78115195544896,
#      'lng': -73.95438304103139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78115195544896,
#        'lng': -73.95438304103139}],
#      'distance': 1051,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10128', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4efdbc040e01089c53931f9e',
#     'name': 'Coffee Cart',
#     'location': {'address': 'West 109th Street',
#      'crossStreet': 'Central Park West',
#      'lat': 40.78602764166895,
#      'lng': -73.96900751780589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78602764166895,
#        'lng': -73.96900751780589}],
#      'distance': 866,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['West 109th Street (Central Park West)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '5017c4c4e4b0ec7798c0f8e5',
#     'name': 'The Coffee Man',
#     'location': {'address': '97th Street',
#      'crossStreet': '3rd Avenue',
#      'lat': 40.786140996650154,
#      'lng': -73.94978476177867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.786140996650154,
#        'lng': -73.94978476177867}],
#      'distance': 936,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['97th Street (3rd Avenue)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4cf511672eb25941b8cbbda1',
#     'name': 'Mount Sinai Medical Center Coffee Stand',
#     'location': {'address': 'Annenberg Building, One Gustave L. Levy Place',
#      'lat': 40.79005300998688,
#      'lng': -73.95348034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79005300998688,
#        'lng': -73.95348034}],
#      'distance': 542,
#      'postalCode': '10029-6574',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Annenberg Building, One Gustave L. Levy Place',
#       'New York, NY 10029-6574',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4dd658e1ae60680f14eaa466',
#     'name': '102nd Street Coffee Cart',
#     'location': {'address': '102nd Street',
#      'crossStreet': 'Madison Avenue',
#      'lat': 40.7916300920085,
#      'lng': -73.95243094600578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7916300920085,
#        'lng': -73.95243094600578}],
#      'distance': 667,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['102nd Street (Madison Avenue)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '52e5571e11d215022eaa9726',
#     'name': 'Coffee and Canvas',
#     'location': {'lat': 40.78114700317383,
#      'lng': -73.94841766357422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78114700317383,
#        'lng': -73.94841766357422}],
#      'distance': 1351,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4e4c3aefbd413c4cc667d310',
#     'name': 'Carnegie Hill Restaurant & Coffee House',
#     'location': {'address': '1361 Lexington Ave',
#      'lat': 40.78218,
#      'lng': -73.95343000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78218,
#        'lng': -73.95343000000001}],
#      'distance': 991,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1361 Lexington Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4e4c5012bd413c4cc6686c3b',
#     'name': 'The Burger One Coffee Shop',
#     'location': {'address': '1364 Lexington Ave',
#      'lat': 40.782352372638236,
#      'lng': -73.95346464542165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.782352372638236,
#        'lng': -73.95346464542165},
#       {'label': 'entrance', 'lat': 40.7823, 'lng': -73.953698}],
#      'distance': 974,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1364 Lexington Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4d7f6bf7b25d6dcb939ecc42',
#     'name': 'Street Coffee Guy',
#     'location': {'address': '5 Avenue A',
#      'crossStreet': '22nd st',
#      'lat': 40.78133022247035,
#      'lng': -73.95925575277442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78133022247035,
#        'lng': -73.95925575277442}],
#      'distance': 924,
#      'postalCode': '10009',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Avenue A (22nd st)',
#       'New York, NY 10009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4b41e508f964a520e5c925e3',
#     'name': 'Louie - Corner Coffee Cart',
#     'location': {'address': '1760 3rd Ave',
#      'crossStreet': '97th street',
#      'lat': 40.786109924316406,
#      'lng': -73.94892883300781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.786109924316406,
#        'lng': -73.94892883300781}],
#      'distance': 1003,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1760 3rd Ave (97th street)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4bc38504abf4952123e0c393',
#     'name': 'Bluestone Lane',
#     'location': {'address': '1085 5th Ave',
#      'crossStreet': 'at 5th Ave',
#      'lat': 40.78375703091576,
#      'lng': -73.95852577546304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78375703091576,
#        'lng': -73.95852577546304},
#       {'label': 'entrance', 'lat': 40.78385, 'lng': -73.958486}],
#      'distance': 663,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1085 5th Ave (at 5th Ave)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2057842',
#      'url': 'https://www.seamless.com/menu/bluestone-lane-caf-1085-5th-ave-new-york/2057842?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2057842',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '49223506'},
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '547c7545498ec5945af05b11',
#     'name': "Pete's Coffee Truck",
#     'location': {'lat': 40.781657074240655,
#      'lng': -73.94935999130517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.781657074240655,
#        'lng': -73.94935999130517}],
#      'distance': 1254,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4a993262f964a5207c2d20e3',
#     'name': 'Starbucks',
#     'location': {'address': '1378 Madison Ave',
#      'crossStreet': 'at E 96th St',
#      'lat': 40.78714,
#      'lng': -73.95448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78714,
#        'lng': -73.95448},
#       {'label': 'entrance', 'lat': 40.787104, 'lng': -73.954409}],
#      'distance': 533,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1378 Madison Ave (at E 96th St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2074738',
#      'url': 'https://www.seamless.com/menu/starbucks-1378-madison-ave-new-york/2074738?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2074738',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4c815832e63376b0a176ac3d',
#     'name': 'Starbucks',
#     'location': {'address': '1491 Lexington Ave',
#      'crossStreet': 'at E 96th St',
#      'lat': 40.78588936,
#      'lng': -73.95083696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78588936,
#        'lng': -73.95083696},
#       {'label': 'entrance', 'lat': 40.786054, 'lng': -73.950651}],
#      'distance': 869,
#      'postalCode': '10029',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1491 Lexington Ave (at E 96th St)',
#       'New York, NY 10029',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2090251',
#      'url': 'https://www.seamless.com/menu/starbucks-1491-lexington-ave-new-york/2090251?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2090251',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4ac3ff4af964a520cc9d20e3',
#     'name': 'Starbucks',
#     'location': {'address': '2498 Broadway',
#      'crossStreet': 'at W 93rd St',
#      'lat': 40.792522,
#      'lng': -73.97303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.792522,
#        'lng': -73.97303}],
#      'distance': 1153,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2498 Broadway (at W 93rd St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2085794',
#      'url': 'https://www.seamless.com/menu/starbucks-2498-broadway-new-york/2085794?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2085794',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4bfaa7ed5ec320a1d2f28bd3',
#     'name': "Juliano's Espresso Bar",
#     'location': {'address': '1378 Lexington Ave',
#      'crossStreet': 'btwn 90th & 91st St',
#      'lat': 40.78267927923873,
#      'lng': -73.9533747231553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78267927923873,
#        'lng': -73.9533747231553},
#       {'label': 'entrance', 'lat': 40.782632, 'lng': -73.953468}],
#      'distance': 948,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1378 Lexington Ave (btwn 90th & 91st St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False},
#    {'id': '4f32292319836c91c7bc2422',
#     'name': "Timothy's Coffees of The World",
#     'location': {'address': '200 E 94th St',
#      'lat': 40.783891,
#      'lng': -73.950282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.783891,
#        'lng': -73.950282}],
#      'distance': 1031,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 E 94th St',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607208425',
#     'hasPerk': False}]}}

# %% [markdown]
# Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
cof_venues = results['response']['venues']

# tranform venues into a dataframe
df_coff = json_normalize(cof_venues)
df_coff.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  5177d30c498e9b657328e30f  Coffee Cart - 97th & Columbus
# 1  4d2fb1575acfa35d7065f2cb          Coffee Cart - 96th St
# 2  58a5d1d426a95370d3355e0d                 WFM Coffee Bar
# 3  5037e21fe4b0b68ee3d6546f                   Birch Coffee
# 4  4d53548e2f638cfa759e616a                         Coffee
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1607208425    False
# 1  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1607208425    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1607208425    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1607208425    False
# 4  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1607208425    False
#
#     location.address     location.crossStreet  location.lat  location.lng  \
# 0      W 97th Street             Columbus Ave     40.794629    -73.966603
# 1           96th St.        Central Park West     40.791754    -73.964864
# 2   808 Columbus Ave                      NaN     40.795145    -73.965855
# 3   750 Columbus Ave  btwn W 96th & W 97th St     40.793131    -73.967241
# 4  43rd And 11th Ave                      NaN     40.792582    -73.965156
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.79462883157771...                793
# 1  [{'label': 'display', 'lat': 40.79175386492058...                481
# 2  [{'label': 'display', 'lat': 40.795145, 'lng':...                793
# 3  [{'label': 'display', 'lat': 40.79313058780598...                731
# 4  [{'label': 'display', 'lat': 40.79258171403207...                552
#
#   location.postalCode location.cc location.city location.state  \
# 0               10025          US      New York             NY
# 1               10025          US      New York             NY
# 2               10025          US      New York             NY
# 3               10025          US      New York             NY
# 4                 NaN          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [W 97th Street (Columbus Ave), New York, NY 10...
# 1    United States  [96th St. (Central Park West), New York, NY 10...
# 2    United States  [808 Columbus Ave, New York, NY 10025, United ...
# 3    United States  [750 Columbus Ave (btwn W 96th & W 97th St), N...
# 4    United States   [43rd And 11th Ave, New York, NY, United States]
#
#   delivery.id delivery.url delivery.provider.name  \
# 0         NaN          NaN                    NaN
# 1         NaN          NaN                    NaN
# 2         NaN          NaN                    NaN
# 3         NaN          NaN                    NaN
# 4         NaN          NaN                    NaN
#
#   delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   delivery.provider.icon.name venuePage.id
# 0                         NaN          NaN
# 1                         NaN          NaN
# 2                         NaN          NaN
# 3                         NaN          NaN
# 4                         NaN          NaN

# %% [markdown]
# Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_coff.columns if col.startswith('location.')] + ['id']
df3_filtered = df_coff.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df3_filtered['categories'] = df3_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df3_filtered.columns = [column.split('.')[-1] for column in df3_filtered.columns]

df3_filtered
# Out:
#                                        name             categories  \
# 0             Coffee Cart - 97th & Columbus             Food Truck
# 1                     Coffee Cart - 96th St             Food Truck
# 2                            WFM Coffee Bar            Coffee Shop
# 3                              Birch Coffee            Coffee Shop
# 4                                    Coffee             Food Truck
# 5                               Coffee Cart             Food Truck
# 6                    Coffee Cart - 103rd St             Food Truck
# 7                            Frenchy Coffee                   Café
# 8                      Coffee & Donuts Cart             Food Truck
# 9              Coffee Cart - 98th & Madison             Food Truck
# 10                  Jack’s Stir Brew Coffee            Coffee Shop
# 11                              Coffee Cart             Food Truck
# 12                           The Coffee Man             Food Truck
# 13  Mount Sinai Medical Center Coffee Stand            Coffee Shop
# 14                 102nd Street Coffee Cart         Breakfast Spot
# 15                        Coffee and Canvas  General Entertainment
# 16  Carnegie Hill Restaurant & Coffee House            Coffee Shop
# 17               The Burger One Coffee Shop           Burger Joint
# 18                        Street Coffee Guy            Coffee Shop
# 19               Louie - Corner Coffee Cart            Coffee Shop
# 20                           Bluestone Lane                   Café
# 21                      Pete's Coffee Truck             Food Truck
# 22                                Starbucks            Coffee Shop
# 23                                Starbucks            Coffee Shop
# 24                                Starbucks            Coffee Shop
# 25                   Juliano's Espresso Bar            Coffee Shop
# 26           Timothy's Coffees of The World                   Food
#
#                                           address  \
# 0                                   W 97th Street
# 1                                        96th St.
# 2                                808 Columbus Ave
# 3                                750 Columbus Ave
# 4                               43rd And 11th Ave
# 5                              85th and Lexington
# 6                                    103rd Street
# 7                                  129 E 102nd St
# 8                          92nd Street & Columbus
# 9                                     98th Street
# 10                                            NaN
# 11                              West 109th Street
# 12                                    97th Street
# 13  Annenberg Building, One Gustave L. Levy Place
# 14                                   102nd Street
# 15                                            NaN
# 16                             1361 Lexington Ave
# 17                             1364 Lexington Ave
# 18                                     5 Avenue A
# 19                                   1760 3rd Ave
# 20                                   1085 5th Ave
# 21                                            NaN
# 22                               1378 Madison Ave
# 23                             1491 Lexington Ave
# 24                                  2498 Broadway
# 25                             1378 Lexington Ave
# 26                                  200 E 94th St
#
#                            crossStreet        lat        lng  \
# 0                         Columbus Ave  40.794629 -73.966603
# 1                    Central Park West  40.791754 -73.964864
# 2                                  NaN  40.795145 -73.965855
# 3              btwn W 96th & W 97th St  40.793131 -73.967241
# 4                                  NaN  40.792582 -73.965156
# 5                                  NaN  40.779683 -73.957511
# 6                                  CPW  40.796066 -73.961586
# 7                                  NaN  40.789873 -73.948341
# 8                                  NaN  40.790062 -73.969147
# 9   Madison Avenue (South East Corner)  40.788527 -73.953016
# 10                                 NaN  40.781152 -73.954383
# 11                   Central Park West  40.786028 -73.969008
# 12                          3rd Avenue  40.786141 -73.949785
# 13                                 NaN  40.790053 -73.953480
# 14                      Madison Avenue  40.791630 -73.952431
# 15                                 NaN  40.781147 -73.948418
# 16                                 NaN  40.782180 -73.953430
# 17                                 NaN  40.782352 -73.953465
# 18                             22nd st  40.781330 -73.959256
# 19                         97th street  40.786110 -73.948929
# 20                          at 5th Ave  40.783757 -73.958526
# 21                                 NaN  40.781657 -73.949360
# 22                        at E 96th St  40.787140 -73.954480
# 23                        at E 96th St  40.785889 -73.950837
# 24                        at W 93rd St  40.792522 -73.973030
# 25                 btwn 90th & 91st St  40.782679 -73.953375
# 26                                 NaN  40.783891 -73.950282
#
#                                        labeledLatLngs  distance  postalCode  \
# 0   [{'label': 'display', 'lat': 40.79462883157771...       793       10025
# 1   [{'label': 'display', 'lat': 40.79175386492058...       481       10025
# 2   [{'label': 'display', 'lat': 40.795145, 'lng':...       793       10025
# 3   [{'label': 'display', 'lat': 40.79313058780598...       731       10025
# 4   [{'label': 'display', 'lat': 40.79258171403207...       552         NaN
# 5   [{'label': 'display', 'lat': 40.77968253446027...      1124         NaN
# 6   [{'label': 'display', 'lat': 40.79606561476228...       731         NaN
# 7   [{'label': 'display', 'lat': 40.7898734, 'lng'...       974       10029
# 8   [{'label': 'display', 'lat': 40.79006195068359...       781       10025
# 9   [{'label': 'display', 'lat': 40.78852683326035...       592       10029
# 10  [{'label': 'display', 'lat': 40.78115195544896...      1051       10128
# 11  [{'label': 'display', 'lat': 40.78602764166895...       866       10025
# 12  [{'label': 'display', 'lat': 40.78614099665015...       936       10029
# 13  [{'label': 'display', 'lat': 40.79005300998688...       542  10029-6574
# 14  [{'label': 'display', 'lat': 40.7916300920085,...       667       10029
# 15  [{'label': 'display', 'lat': 40.78114700317383...      1351         NaN
# 16  [{'label': 'display', 'lat': 40.78218, 'lng': ...       991       10128
# 17  [{'label': 'display', 'lat': 40.78235237263823...       974       10128
# 18  [{'label': 'display', 'lat': 40.78133022247035...       924       10009
# 19  [{'label': 'display', 'lat': 40.78610992431640...      1003       10029
# 20  [{'label': 'display', 'lat': 40.78375703091576...       663       10128
# 21  [{'label': 'display', 'lat': 40.78165707424065...      1254         NaN
# 22  [{'label': 'display', 'lat': 40.78714, 'lng': ...       533       10128
# 23  [{'label': 'display', 'lat': 40.78588936, 'lng...       869       10029
# 24  [{'label': 'display', 'lat': 40.792522, 'lng':...      1153       10025
# 25  [{'label': 'display', 'lat': 40.78267927923873...       948       10128
# 26  [{'label': 'display', 'lat': 40.783891, 'lng':...      1031       10128
#
#     cc      city state        country  \
# 0   US  New York    NY  United States
# 1   US  New York    NY  United States
# 2   US  New York    NY  United States
# 3   US  New York    NY  United States
# 4   US  New York    NY  United States
# 5   US  New York    NY  United States
# 6   US  New York    NY  United States
# 7   US  New York    NY  United States
# 8   US  New York    NY  United States
# 9   US  New York    NY  United States
# 10  US  New York    NY  United States
# 11  US  New York    NY  United States
# 12  US  New York    NY  United States
# 13  US  New York    NY  United States
# 14  US  New York    NY  United States
# 15  US  New York    NY  United States
# 16  US  New York    NY  United States
# 17  US  New York    NY  United States
# 18  US  New York    NY  United States
# 19  US  New York    NY  United States
# 20  US  New York    NY  United States
# 21  US  New York    NY  United States
# 22  US  New York    NY  United States
# 23  US  New York    NY  United States
# 24  US  New York    NY  United States
# 25  US  New York    NY  United States
# 26  US  New York    NY  United States
#
#                                      formattedAddress  \
# 0   [W 97th Street (Columbus Ave), New York, NY 10...
# 1   [96th St. (Central Park West), New York, NY 10...
# 2   [808 Columbus Ave, New York, NY 10025, United ...
# 3   [750 Columbus Ave (btwn W 96th & W 97th St), N...
# 4    [43rd And 11th Ave, New York, NY, United States]
# 5   [85th and Lexington, New York, NY, United States]
# 6   [103rd Street (CPW), New York, NY, United States]
# 7   [129 E 102nd St, New York, NY 10029, United St...
# 8   [92nd Street & Columbus, New York, NY 10025, U...
# 9   [98th Street (Madison Avenue (South East Corne...
# 10                [New York, NY 10128, United States]
# 11  [West 109th Street (Central Park West), New Yo...
# 12  [97th Street (3rd Avenue), New York, NY 10029,...
# 13  [Annenberg Building, One Gustave L. Levy Place...
# 14  [102nd Street (Madison Avenue), New York, NY 1...
# 15                      [New York, NY, United States]
# 16  [1361 Lexington Ave, New York, NY 10128, Unite...
# 17  [1364 Lexington Ave, New York, NY 10128, Unite...
# 18  [5 Avenue A (22nd st), New York, NY 10009, Uni...
# 19  [1760 3rd Ave (97th street), New York, NY 1002...
# 20  [1085 5th Ave (at 5th Ave), New York, NY 10128...
# 21                      [New York, NY, United States]
# 22  [1378 Madison Ave (at E 96th St), New York, NY...
# 23  [1491 Lexington Ave (at E 96th St), New York, ...
# 24  [2498 Broadway (at W 93rd St), New York, NY 10...
# 25  [1378 Lexington Ave (btwn 90th & 91st St), New...
# 26  [200 E 94th St, New York, NY 10128, United Sta...
#
#                           id
# 0   5177d30c498e9b657328e30f
# 1   4d2fb1575acfa35d7065f2cb
# 2   58a5d1d426a95370d3355e0d
# 3   5037e21fe4b0b68ee3d6546f
# 4   4d53548e2f638cfa759e616a
# 5   4dca7fde1f6e28126777d908
# 6   4f6243bae4b0a20e1e91aabf
# 7   5a772c1625ecca5ea8cd01cd
# 8   4fdb2abfe4b0cbb58909cb7b
# 9   4bdb92b7383276b0c8b67369
# 10  5b784d8d037be1002c195155
# 11  4efdbc040e01089c53931f9e
# 12  5017c4c4e4b0ec7798c0f8e5
# 13  4cf511672eb25941b8cbbda1
# 14  4dd658e1ae60680f14eaa466
# 15  52e5571e11d215022eaa9726
# 16  4e4c3aefbd413c4cc667d310
# 17  4e4c5012bd413c4cc6686c3b
# 18  4d7f6bf7b25d6dcb939ecc42
# 19  4b41e508f964a520e5c925e3
# 20  4bc38504abf4952123e0c393
# 21  547c7545498ec5945af05b11
# 22  4a993262f964a5207c2d20e3
# 23  4c815832e63376b0a176ac3d
# 24  4ac3ff4af964a520cc9d20e3
# 25  4bfaa7ed5ec320a1d2f28bd3
# 26  4f32292319836c91c7bc2422

# %% [markdown]
# Visualizing the Coffee shops that are near by

# %%
df3_filtered.name
# Out:
# 0               Coffee Cart - 97th & Columbus
# 1                       Coffee Cart - 96th St
# 2                              WFM Coffee Bar
# 3                                Birch Coffee
# 4                                      Coffee
# 5                                 Coffee Cart
# 6                      Coffee Cart - 103rd St
# 7                              Frenchy Coffee
# 8                        Coffee & Donuts Cart
# 9                Coffee Cart - 98th & Madison
# 10                    Jack’s Stir Brew Coffee
# 11                                Coffee Cart
# 12                             The Coffee Man
# 13    Mount Sinai Medical Center Coffee Stand
# 14                   102nd Street Coffee Cart
# 15                          Coffee and Canvas
# 16    Carnegie Hill Restaurant & Coffee House
# 17                 The Burger One Coffee Shop
# 18                          Street Coffee Guy
# 19                 Louie - Corner Coffee Cart
# 20                             Bluestone Lane
# 21                        Pete's Coffee Truck
# 22                                  Starbucks
# 23                                  Starbucks
# 24                                  Starbucks
# 25                     Juliano's Espresso Bar
# 26             Timothy's Coffees of The World
# Name: name, dtype: object

# %%
# generate map centred around the Manhattan area
coffvenues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(df3_filtered.lat, df3_filtered.lng, df3_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(coffvenues_map)

# display map
coffvenues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
